# %% [markdown]
# # PyTorch
#
# <img src="https://docs.pytorch.org/docs/stable/_static/img/logo.svg" alt="PyTorch Logo" width="300" style="background-color:black;"/>
#
# Doc: <https://pytorch.org/docs/stable/index.html>
