# %% [markdown]
# # Matplotlib & Seaborn & Plotly
#
# ## Matplotlib
#
# <img src="https://matplotlib.org/stable/_static/logo_light.svg" alt="Matplotlib Logo" width="300"/>
#
# Doc: <https://matplotlib.org/stable/api/index>

# %% [markdown]
# ## Seaborn
#
# <img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg" alt="Seaborn Logo" width="300"/>
#
# Doc: <https://seaborn.pydata.org/api.html>

# %% [markdown]
# # Plotly
#
# <img src="https://plotly.com/all_static/images/graphing_library.svg" alt="Plotly Logo" width="500" style="background-color:black;"/>
#
# Doc: <https://plotly.com/python/>
